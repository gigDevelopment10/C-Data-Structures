# %% [markdown]
# <a href="https://colab.research.google.com/github/gigDevelopment10/C-Data-Structures/blob/main/Finaldoc_Ultrahackers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/UltraHackers/train_data
# Out:
# /content/drive/MyDrive/UltraHackers/train_data

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12148, done.
# remote: Total 12148 (delta 0), reused 0 (delta 0), pack-reused 12148
# Receiving objects: 100% (12148/12148), 11.47 MiB | 5.76 MiB/s, done.
# Resolving deltas: 100% (8439/8439), done.
# /content/drive/MyDrive/UltraHackers/train_data/yolov5
#      |████████████████████████████████| 596 kB 4.3 MB/s

# %%
pwd
# Out:
# '/content/drive/MyDrive/UltraHackers/train_data/yolov5'

# %%
cd /content/drive/MyDrive/UltraHackers/train_data/yolov5
# Out:
# /content/drive/MyDrive/UltraHackers/train_data/yolov5

# %%
import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.9/78.2 GB disk)

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python train.py --img 640 --batch 24 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=24, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/UltraHackers/train_data/yolov5/runs/train/exp4/weights/best.pt  --img 640 --conf 0.25 --source /content/images.jpg
# Out:
# detect: weights=['/content/drive/MyDrive/UltraHackers/train_data/yolov5/runs/train/exp4/weights/best.pt'], source=/content/images.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/images.jpg: 448x640 Done. (0.028s)
# Speed: 0.5ms pre-process, 27.8ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
# model for seal

# %%
cd /content/drive/MyDrive/UltraHackers/train_data2
# Out:
# /content/drive/MyDrive/UltraHackers/train_data2

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12148, done.
# remote: Total 12148 (delta 0), reused 0 (delta 0), pack-reused 12148
# Receiving objects: 100% (12148/12148), 11.42 MiB | 6.69 MiB/s, done.
# Resolving deltas: 100% (8441/8441), done.
# /content/drive/MyDrive/UltraHackers/train_data2/yolov5

# %%
import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 40.1/78.2 GB disk)

# %%
pwd
# Out:
# '/content/drive/MyDrive/UltraHackers/train_data/yolov5'

# %%
# !python train.py --img 640 --batch 24 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache

# %%
#inference for turtle (exp4)

# %%
# !python detect.py --weights /content/drive/MyDrive/UltraHackers/train_data/yolov5/runs/train/exp4/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/UltraHackers/Results/turtle.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/UltraHackers/train_data/yolov5/runs/train/exp4/weights/best.pt'], source=/content/drive/MyDrive/UltraHackers/Results/turtle.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/1800) /content/drive/MyDrive/UltraHackers/Results/turtle.mp4: 384x640 1 turtle_stuck, Done. (0.027s)
# video 1/1 (2/1800) /content/drive/MyDrive/UltraHackers/Results/turtle.mp4: 384x640 1 turtle_stuck, Done. (0.027s)
# ...

# %%
#inference for seal (exp2)

# %%
# !python detect.py --weights /content/drive/MyDrive/UltraHackers/train_data2/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/UltraHackers/Results/seal.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/UltraHackers/train_data2/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/UltraHackers/Results/seal.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/3176) /content/drive/MyDrive/UltraHackers/Results/seal.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/3176) /content/drive/MyDrive/UltraHackers/Results/seal.mp4: 384x640 Done. (0.027s)
# ...

# %%
cd /content/drive/MyDrive/UltraHackers/train_data/yolov5
# Out:
# /content/drive/MyDrive/UltraHackers/train_data/yolov5
